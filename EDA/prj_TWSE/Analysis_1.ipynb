# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
#plt.style.use('fivethirtyeight')

# %% [markdown]
# # 使用finlab API
# https://ai.finlab.tw/database/
#
# # 目的 ： 透過機器學股票預測, 來做某檔股票進出場的建議.
#     * 假設情境是每兩個的做一次進出場決策.
#     1. 預測標的 : 2個禮拜後的平均股價 (透過機器學習找到最適合的區段)
#
#         目前結論 :
#             1. 相比 Time-Series 使用 K-Fold 的方式去訓練可以達到比較好的預測力.
#             2. 其他股票 例如 台積電 無法使用此方法預測
#
#
#
# * 研究遠傳 ( 4904 )股票
#     * 基本 Time-Series EDA
#     * 製作變數
#         * 遠傳本身
#             * moving_avg
#     * 股價預測模型
#         * Time-Series Split
#         * K-Fold Split
#
#     * 找 Correlation 高的股票
#         * 增加 Correlation 高的股票的變數

# %%
close = pd.read_pickle('/Users/kevintsai/Google Drive/My Drive/finlab_db/price#收盤價.pickle')
volume = pd.read_pickle('/Users/kevintsai/Google Drive/My Drive/finlab_db/price#成交股數.pickle')
transaction = pd.read_pickle('/Users/kevintsai/Google Drive/My Drive/finlab_db/price#成交筆數.pickle')
price = pd.read_pickle('/Users/kevintsai/Google Drive/My Drive/finlab_db/price#成交金額.pickle')

# %%
close.head(5)
# Out:
# symbol      0015   0050   0051   0052  0053  0054  0055  0056  0057  0058  \
# date
# 2007-04-23  9.54  57.85  32.83  38.40   NaN   NaN   NaN   NaN   NaN   NaN
# 2007-04-24  9.54  58.10  32.99  38.65   NaN   NaN   NaN   NaN   NaN   NaN
# 2007-04-25  9.52  57.60  32.80  38.59   NaN   NaN   NaN   NaN   NaN   NaN
# 2007-04-26  9.59  57.70  32.80  38.60   NaN   NaN   NaN   NaN   NaN   NaN
# 2007-04-27  9.55  57.50  32.72  38.40   NaN   NaN   NaN   NaN   NaN   NaN
#
# symbol      ...  9944   9945   9946  9949   9950  9951  9955  9958  9960  9962
# date        ...
# 2007-04-23  ...  31.0  30.35   9.78  73.6  13.25  51.3  72.4   NaN  46.0  49.6
# 2007-04-24  ...  32.0  30.50   9.91  75.0  13.25  50.5  71.6   NaN  45.9  50.4
# 2007-04-25  ...  32.3  29.50  10.10  74.6  13.30  49.9  71.6   NaN  49.1  49.1
# 2007-04-26  ...  31.6  29.15  10.80  74.5  13.25  49.5  71.0   NaN  48.9  48.0
# 2007-04-27  ...  31.4  28.50  11.55  75.7  13.15  48.8  69.5   NaN  48.6  46.5
#
# [5 rows x 2398 columns]

# %%
volume.head(5)
# Out:
# symbol          0015       0050      0051      0052  0053  0054  0055  0056  \
# date
# 2007-04-23  104000.0  8571000.0  779000.0  104000.0   NaN   NaN   NaN   NaN
# 2007-04-24  187000.0  2483010.0  287100.0  221000.0   NaN   NaN   NaN   NaN
# 2007-04-25   90000.0  1232000.0  138000.0  194000.0   NaN   NaN   NaN   NaN
# 2007-04-26  102000.0  6357000.0  110001.0  137001.0   NaN   NaN   NaN   NaN
# 2007-04-27   26000.0  1070000.0  100000.0  146229.0   NaN   NaN   NaN   NaN
#
# symbol      0057  0058  ...       9944        9945      9946      9949  \
# date                    ...
# 2007-04-23   NaN   NaN  ...   721146.0  25049679.0   35957.0  464653.0
# 2007-04-24   NaN   NaN  ...  1805000.0  15306352.0   52090.0  286392.0
# 2007-04-25   NaN   NaN  ...  2262711.0   9530053.0   57403.0  183000.0
# 2007-04-26   NaN   NaN  ...  1114521.0   7677908.0  326998.0  306539.0
# 2007-04-27   NaN   NaN  ...   813050.0  15485927.0  482872.0  174175.0
#
# symbol         9950      9951       9955  9958      9960       9962
# date
# 2007-04-23   8000.0  355794.0  1163530.0   NaN  413406.0   751560.0
# 2007-04-24   9000.0  140200.0   925687.0   NaN  271693.0  1566560.0
# 2007-04-25  16000.0  269570.0   847400.0   NaN  365100.0   983002.0
# 2007-04-26  14000.0  131000.0   567750.0   NaN  254348.0  1754381.0
# 2007-04-27  24000.0  125000.0   685194.0   NaN   75900.0  1776000.0
#
# [5 rows x 2398 columns]

# %%
# 遠傳 : 4904
# 中華電 : 2412
# 台灣大 : 3045
# 台積電 : 2330
target = '3045'


df_close = pd.DataFrame(close[[target,'0050']]).copy()
df_close.columns = [target+'_close', '0050_close']

df_volume = pd.DataFrame(volume[[target,'0050']]).copy()
df_volume.columns = [target+'_volume', '0050_volume']

df_transaction = pd.DataFrame(close[[target,'0050']]).copy()
df_transaction.columns = [target+'_transaction', '0050_transaction']

df_price = pd.DataFrame(close[[target,'0050']]).copy()
df_price.columns = [target+'_price', '0050_price']

# %% [markdown]
# # Visualise Data

# %%
fig, axs = plt.subplots(4,1
                        , figsize=(15,15)
                        ,sharex=True)


sns.lineplot(ax = axs[3]
             , data = df_close
             , palette=['orange','black']
             #, ls = ['','--' ]
             )

sns.lineplot(ax = axs[2]
             ,data = df_transaction
             , palette=['orange','black']
             #, ls = ['','--' ]
             )


sns.lineplot( ax = axs[1]
             , data = df_volume
             , palette=['orange','black']
             #, ls = ['','--' ]
             )


sns.lineplot(ax = axs[0]
             , data = df_price
             , palette=['orange','black']
             #, ls = ['','--' ]
             )


plt.show()

# %%
#Post 2014 is more stable 
#df = df.loc[df.index >= '2014-01-01'].copy()

# %%
def add_date_features(df):
    df = df.copy()

    df['feature_dayofweek'] = df.index.day_of_week
    df['feature_day'] = df.index.day
    df['feature_quarter'] = df.index.quarter
    df['feature_month'] = df.index.month
    df['feature_year'] = df.index.year
    df['feature_dayofyear'] = df.index.dayofyear

    return df

# %%
df_close = add_date_features(df_close)

# %%
# check for seasonallity

fig, ax = plt.subplots(figsize=(10,4))
sns.boxplot(data=df_close
            , x='feature_month'
            , y=target + '_close'
            )

ax.set_title(target + ' by Month')
# Out:
# Text(0.5, 1.0, '3045 by Month')

# %% [markdown]
# # Feature Creation
#     * moving average
#     * slope

# %%
def add_close_feature (close_df, target):
    close_df = close_df.copy()

    # moving average
    close_df[target + '_feature_close_avg_5_days'] = close_df[target + '_close'].rolling(5).mean()
    close_df[target + '_feature_close_avg_10_days'] = close_df[target + '_close'].rolling(10).mean()
    close_df[target + '_feature_close_avg_20_days'] = close_df[target + '_close'].rolling(20).mean()
    close_df[target + '_feature_close_avg_30_days'] = close_df[target + '_close'].rolling(30).mean()

    # slope
    close_df[target + '_feature_close_avg_slope_5_10_days'] = (close_df[target + '_feature_close_avg_5_days'] / close_df[target + '_feature_close_avg_10_days']).round(5)
    close_df[target + '_feature_close_avg_slope_5_20_days'] = (close_df[target + '_feature_close_avg_5_days'] / close_df[target + '_feature_close_avg_20_days']).round(5)
    close_df[target + '_feature_close_avg_slope_5_30_days'] = (close_df[target + '_feature_close_avg_5_days'] / close_df[target + '_feature_close_avg_30_days']).round(5)
    
    close_df[target + '_feature_close_avg_slope_10_20_days'] = (close_df[target + '_feature_close_avg_10_days'] / close_df[target + '_feature_close_avg_20_days']).round(5)
    close_df[target + '_feature_close_avg_slope_10_30_days'] = (close_df[target + '_feature_close_avg_10_days'] / close_df[target + '_feature_close_avg_30_days']).round(5)

    close_df[target + '_feature_close_avg_slope_20_30_days'] = (close_df[target + '_feature_close_avg_20_days'] / close_df[target + '_feature_close_avg_30_days']).round(5)

    return close_df  

def add_volume_feature (volume_df, target):
    volume_df = volume_df.copy()

    # moving average
    volume_df[target + '_feature_volume_avg_5_days'] = volume_df[target + '_volume'].rolling(5).mean()
    volume_df[target + '_feature_volume_avg_10_days'] = volume_df[target + '_volume'].rolling(10).mean()
    volume_df[target + '_feature_volume_avg_20_days'] = volume_df[target + '_volume'].rolling(20).mean()
    volume_df[target + '_feature_volume_avg_30_days'] = volume_df[target + '_volume'].rolling(30).mean()

    # slope
    volume_df[target + '_feature_volume_avg_slope_5_10_days'] = (volume_df[target + '_feature_volume_avg_5_days'] / volume_df[target + '_feature_volume_avg_10_days']).round(5)
    volume_df[target + '_feature_volume_avg_slope_5_20_days'] = (volume_df[target + '_feature_volume_avg_5_days'] / volume_df[target + '_feature_volume_avg_20_days']).round(5)
    volume_df[target + '_feature_volume_avg_slope_5_30_days'] = (volume_df[target + '_feature_volume_avg_5_days'] / volume_df[target + '_feature_volume_avg_30_days']).round(5)
    
    volume_df[target + '_feature_volume_avg_slope_10_20_days'] = (volume_df[target + '_feature_volume_avg_10_days'] / volume_df[target + '_feature_volume_avg_20_days']).round(5)
    volume_df[target + '_feature_volume_avg_slope_10_30_days'] = (volume_df[target + '_feature_volume_avg_10_days'] / volume_df[target + '_feature_volume_avg_30_days']).round(5)

    volume_df[target + '_feature_volume_avg_slope_20_30_days'] = (volume_df[target + '_feature_volume_avg_20_days'] / volume_df[target + '_feature_volume_avg_30_days']).round(5)

    return volume_df  

def add_transaction_feature (transaction_df, target):
    transaction_df = transaction_df.copy()

    # moving average
    transaction_df[target + '_feature_transaction_avg_5_days'] = transaction_df[target + '_transaction'].rolling(5).mean()
    transaction_df[target + '_feature_transaction_avg_10_days'] = transaction_df[target + '_transaction'].rolling(10).mean()
    transaction_df[target + '_feature_transaction_avg_20_days'] = transaction_df[target + '_transaction'].rolling(20).mean()
    transaction_df[target + '_feature_transaction_avg_30_days'] = transaction_df[target + '_transaction'].rolling(30).mean()

    # slope
    transaction_df[target + '_feature_transaction_avg_slope_5_10_days'] = (transaction_df[target + '_feature_transaction_avg_5_days'] / transaction_df[target + '_feature_transaction_avg_10_days']).round(5)
    transaction_df[target + '_feature_transaction_avg_slope_5_20_days'] = (transaction_df[target + '_feature_transaction_avg_5_days'] / transaction_df[target + '_feature_transaction_avg_20_days']).round(5)
    transaction_df[target + '_feature_transaction_avg_slope_5_30_days'] = (transaction_df[target + '_feature_transaction_avg_5_days'] / transaction_df[target + '_feature_transaction_avg_30_days']).round(5)
    
    transaction_df[target + '_feature_transaction_avg_slope_10_20_days'] = (transaction_df[target + '_feature_transaction_avg_10_days'] / transaction_df[target + '_feature_transaction_avg_20_days']).round(5)
    transaction_df[target + '_feature_transaction_avg_slope_10_30_days'] = (transaction_df[target + '_feature_transaction_avg_10_days'] / transaction_df[target + '_feature_transaction_avg_30_days']).round(5)

    transaction_df[target + '_feature_transaction_avg_slope_20_30_days'] = (transaction_df[target + '_feature_transaction_avg_20_days'] / transaction_df[target + '_feature_transaction_avg_30_days']).round(5)

    return transaction_df  

def add_price_feature (price_df, target):
    price_df = price_df.copy()

    # moving average
    price_df[target + '_feature_price_avg_5_days'] = price_df[target + '_price'].rolling(5).mean()
    price_df[target + '_feature_price_avg_10_days'] = price_df[target + '_price'].rolling(10).mean()
    price_df[target + '_feature_price_avg_20_days'] = price_df[target + '_price'].rolling(20).mean()
    price_df[target + '_feature_price_avg_30_days'] = price_df[target + '_price'].rolling(30).mean()

    # slope
    price_df[target + '_feature_price_avg_slope_5_10_days'] = (price_df[target + '_feature_price_avg_5_days'] / price_df[target + '_feature_price_avg_10_days']).round(5)
    price_df[target + '_feature_price_avg_slope_5_20_days'] = (price_df[target + '_feature_price_avg_5_days'] / price_df[target + '_feature_price_avg_20_days']).round(5)
    price_df[target + '_feature_price_avg_slope_5_30_days'] = (price_df[target + '_feature_price_avg_5_days'] / price_df[target + '_feature_price_avg_30_days']).round(5)
    
    price_df[target + '_feature_price_avg_slope_10_20_days'] = (price_df[target + '_feature_price_avg_10_days'] / price_df[target + '_feature_price_avg_20_days']).round(5)
    price_df[target + '_feature_price_avg_slope_10_30_days'] = (price_df[target + '_feature_price_avg_10_days'] / price_df[target + '_feature_price_avg_30_days']).round(5)

    price_df[target + '_feature_price_avg_slope_20_30_days'] = (price_df[target + '_feature_price_avg_20_days'] / price_df[target + '_feature_price_avg_30_days']).round(5)

    return price_df

# %%
# create predictoin target == 10 day rolling avg in 2wks time 

model_close_data  = add_close_feature(df_close.sort_index(), target)
model_volume_data  = add_volume_feature(df_volume.sort_index(), target)
model_transaction_data  = add_transaction_feature(df_transaction.sort_index(), target)
model_price_data  = add_price_feature(df_price.sort_index(), target)

model_close_data = model_close_data.sort_index()

 
model_close_data[target + '_y'] = model_close_data.shift(-20)[target + '_feature_close_avg_5_days']

model_data = (model_close_data
              .join(model_volume_data)
              .join(model_transaction_data)
              .join(model_price_data)
              )

# %%
#(model_close_data.loc['2022-01-01':'2022-03-01', ['2330_close', '2330_feature_close_avg_5_days', '2330_y']]).to_clipboard()

# %%
model_data.tail(5).transpose()
# Out:
# date                                             2023-05-31    2023-06-01  \
# 3045_close                                     1.035000e+02  1.030000e+02
# 0050_close                                     1.261500e+02  1.251500e+02
# feature_dayofweek                              2.000000e+00  3.000000e+00
# feature_day                                    3.100000e+01  1.000000e+00
# feature_quarter                                2.000000e+00  2.000000e+00
# feature_month                                  5.000000e+00  6.000000e+00
# feature_year                                   2.023000e+03  2.023000e+03
# feature_dayofyear                              1.510000e+02  1.520000e+02
# 3045_feature_close_avg_5_days                  1.031000e+02  1.032000e+02
# 3045_feature_close_avg_10_days                 1.035500e+02  1.034500e+02
# 3045_feature_close_avg_20_days                 1.036750e+02  1.036000e+02
# 3045_feature_close_avg_30_days                 1.035333e+02  1.035000e+02
# 3045_feature_close_avg_slope_5_10_days         9.956500e-01  9.975800e-01
# 3045_feature_close_avg_slope_5_20_days         9.944500e-01  9.961400e-01
# 3045_feature_close_avg_slope_5_30_days         9.958100e-01  9.971000e-01
# 3045_feature_close_avg_slope_10_20_days        9.987900e-01  9.985500e-01
# 3045_feature_close_avg_slope_10_30_days        1.000160e+00  9.995200e-01
# 3045_feature_close_avg_slope_20_30_days        1.001370e+00  1.000970e+00
# 3045_y                                                  NaN           NaN
# 3045_volume                                    1.714681e+07  3.729657e+06
# 0050_volume                                    9.229280e+06  4.231123e+06
# 3045_feature_volume_avg_5_days                 8.027728e+06  7.391598e+06
# 3045_feature_volume_avg_10_days                5.979603e+06  6.038709e+06
# 3045_feature_volume_avg_20_days                4.557323e+06  4.509689e+06
# 3045_feature_volume_avg_30_days                4.052323e+06  4.079129e+06
# 3045_feature_volume_avg_slope_5_10_days        1.342520e+00  1.224040e+00
# 3045_feature_volume_avg_slope_5_20_days        1.761500e+00  1.639050e+00
# 3045_feature_volume_avg_slope_5_30_days        1.981020e+00  1.812050e+00
# 3045_feature_volume_avg_slope_10_20_days       1.312090e+00  1.339050e+00
# 3045_feature_volume_avg_slope_10_30_days       1.475600e+00  1.480390e+00
# 3045_feature_volume_avg_slope_20_30_days       1.124620e+00  1.105550e+00
# 3045_transaction                               1.035000e+02  1.030000e+02
# 0050_transaction                               1.261500e+02  1.251500e+02
# 3045_feature_transaction_avg_5_days            1.031000e+02  1.032000e+02
# 3045_feature_transaction_avg_10_days           1.035500e+02  1.034500e+02
# 3045_feature_transaction_avg_20_days           1.036750e+02  1.036000e+02
# 3045_feature_transaction_avg_30_days           1.035333e+02  1.035000e+02
# 3045_feature_transaction_avg_slope_5_10_days   9.956500e-01  9.975800e-01
# 3045_feature_transaction_avg_slope_5_20_days   9.944500e-01  9.961400e-01
# 3045_feature_transaction_avg_slope_5_30_days   9.958100e-01  9.971000e-01
# 3045_feature_transaction_avg_slope_10_20_days  9.987900e-01  9.985500e-01
# 3045_feature_transaction_avg_slope_10_30_days  1.000160e+00  9.995200e-01
# 3045_feature_transaction_avg_slope_20_30_days  1.001370e+00  1.000970e+00
# 3045_price                                     1.035000e+02  1.030000e+02
# 0050_price                                     1.261500e+02  1.251500e+02
# 3045_feature_price_avg_5_days                  1.031000e+02  1.032000e+02
# 3045_feature_price_avg_10_days                 1.035500e+02  1.034500e+02
# 3045_feature_price_avg_20_days                 1.036750e+02  1.036000e+02
# 3045_feature_price_avg_30_days                 1.035333e+02  1.035000e+02
# 3045_feature_price_avg_slope_5_10_days         9.956500e-01  9.975800e-01
# 3045_feature_price_avg_slope_5_20_days         9.944500e-01  9.961400e-01
# 3045_feature_price_avg_slope_5_30_days         9.958100e-01  9.971000e-01
# 3045_feature_price_avg_slope_10_20_days        9.987900e-01  9.985500e-01
# 3045_feature_price_avg_slope_10_30_days        1.000160e+00  9.995200e-01
# 3045_feature_price_avg_slope_20_30_days        1.001370e+00  1.000970e+00
#
# date                                             2023-06-02    2023-06-05  \
# 3045_close                                     1.040000e+02  1.035000e+02
# 0050_close                                     1.267500e+02  1.263500e+02
# feature_dayofweek                              4.000000e+00  0.000000e+00
# feature_day                                    2.000000e+00  5.000000e+00
# feature_quarter                                2.000000e+00  2.000000e+00
# feature_month                                  6.000000e+00  6.000000e+00
# feature_year                                   2.023000e+03  2.023000e+03
# feature_dayofyear                              1.530000e+02  1.560000e+02
# 3045_feature_close_avg_5_days                  1.034000e+02  1.035000e+02
# 3045_feature_close_avg_10_days                 1.034500e+02  1.034000e+02
# 3045_feature_close_avg_20_days                 1.035750e+02  1.035500e+02
# 3045_feature_close_avg_30_days                 1.035333e+02  1.035667e+02
# 3045_feature_close_avg_slope_5_10_days         9.995200e-01  1.000970e+00
# 3045_feature_close_avg_slope_5_20_days         9.983100e-01  9.995200e-01
# 3045_feature_close_avg_slope_5_30_days         9.987100e-01  9.993600e-01
# 3045_feature_close_avg_slope_10_20_days        9.987900e-01  9.985500e-01
# 3045_feature_close_avg_slope_10_30_days        9.992000e-01  9.983900e-01
# 3045_feature_close_avg_slope_20_30_days        1.000400e+00  9.998400e-01
# 3045_y                                                  NaN           NaN
# 3045_volume                                    4.924053e+06  2.449026e+06
# 0050_volume                                    8.412015e+06  6.813168e+06
# 3045_feature_volume_avg_5_days                 7.346385e+06  6.964324e+06
# 3045_feature_volume_avg_10_days                6.093656e+06  5.961746e+06
# 3045_feature_volume_avg_20_days                4.581283e+06  4.595702e+06
# 3045_feature_volume_avg_30_days                4.039912e+06  3.989699e+06
# 3045_feature_volume_avg_slope_5_10_days        1.205580e+00  1.168170e+00
# 3045_feature_volume_avg_slope_5_20_days        1.603560e+00  1.515400e+00
# 3045_feature_volume_avg_slope_5_30_days        1.818450e+00  1.745580e+00
# 3045_feature_volume_avg_slope_10_20_days       1.330120e+00  1.297240e+00
# 3045_feature_volume_avg_slope_10_30_days       1.508360e+00  1.494280e+00
# 3045_feature_volume_avg_slope_20_30_days       1.134010e+00  1.151890e+00
# 3045_transaction                               1.040000e+02  1.035000e+02
# 0050_transaction                               1.267500e+02  1.263500e+02
# 3045_feature_transaction_avg_5_days            1.034000e+02  1.035000e+02
# 3045_feature_transaction_avg_10_days           1.034500e+02  1.034000e+02
# 3045_feature_transaction_avg_20_days           1.035750e+02  1.035500e+02
# 3045_feature_transaction_avg_30_days           1.035333e+02  1.035667e+02
# 3045_feature_transaction_avg_slope_5_10_days   9.995200e-01  1.000970e+00
# 3045_feature_transaction_avg_slope_5_20_days   9.983100e-01  9.995200e-01
# 3045_feature_transaction_avg_slope_5_30_days   9.987100e-01  9.993600e-01
# 3045_feature_transaction_avg_slope_10_20_days  9.987900e-01  9.985500e-01
# 3045_feature_transaction_avg_slope_10_30_days  9.992000e-01  9.983900e-01
# 3045_feature_transaction_avg_slope_20_30_days  1.000400e+00  9.998400e-01
# 3045_price                                     1.040000e+02  1.035000e+02
# 0050_price                                     1.267500e+02  1.263500e+02
# 3045_feature_price_avg_5_days                  1.034000e+02  1.035000e+02
# 3045_feature_price_avg_10_days                 1.034500e+02  1.034000e+02
# 3045_feature_price_avg_20_days                 1.035750e+02  1.035500e+02
# 3045_feature_price_avg_30_days                 1.035333e+02  1.035667e+02
# 3045_feature_price_avg_slope_5_10_days         9.995200e-01  1.000970e+00
# 3045_feature_price_avg_slope_5_20_days         9.983100e-01  9.995200e-01
# 3045_feature_price_avg_slope_5_30_days         9.987100e-01  9.993600e-01
# 3045_feature_price_avg_slope_10_20_days        9.987900e-01  9.985500e-01
# 3045_feature_price_avg_slope_10_30_days        9.992000e-01  9.983900e-01
# 3045_feature_price_avg_slope_20_30_days        1.000400e+00  9.998400e-01
#
# date                                             2023-06-06
# 3045_close                                     1.040000e+02
# 0050_close                                     1.267000e+02
# feature_dayofweek                              1.000000e+00
# feature_day                                    6.000000e+00
# feature_quarter                                2.000000e+00
# feature_month                                  6.000000e+00
# feature_year                                   2.023000e+03
# feature_dayofyear                              1.570000e+02
# 3045_feature_close_avg_5_days                  1.036000e+02
# 3045_feature_close_avg_10_days                 1.034000e+02
# 3045_feature_close_avg_20_days                 1.035750e+02
# 3045_feature_close_avg_30_days                 1.036000e+02
# 3045_feature_close_avg_slope_5_10_days         1.001930e+00
# 3045_feature_close_avg_slope_5_20_days         1.000240e+00
# 3045_feature_close_avg_slope_5_30_days         1.000000e+00
# 3045_feature_close_avg_slope_10_20_days        9.983100e-01
# 3045_feature_close_avg_slope_10_30_days        9.980700e-01
# 3045_feature_close_avg_slope_20_30_days        9.997600e-01
# 3045_y                                                  NaN
# 3045_volume                                    4.692109e+06
# 0050_volume                                    6.877372e+06
# 3045_feature_volume_avg_5_days                 6.588332e+06
# 3045_feature_volume_avg_10_days                5.994502e+06
# 3045_feature_volume_avg_20_days                4.675019e+06
# 3045_feature_volume_avg_30_days                4.088807e+06
# 3045_feature_volume_avg_slope_5_10_days        1.099060e+00
# 3045_feature_volume_avg_slope_5_20_days        1.409260e+00
# 3045_feature_volume_avg_slope_5_30_days        1.611310e+00
# 3045_feature_volume_avg_slope_10_20_days       1.282240e+00
# 3045_feature_volume_avg_slope_10_30_days       1.466080e+00
# 3045_feature_volume_avg_slope_20_30_days       1.143370e+00
# 3045_transaction                               1.040000e+02
# 0050_transaction                               1.267000e+02
# 3045_feature_transaction_avg_5_days            1.036000e+02
# 3045_feature_transaction_avg_10_days           1.034000e+02
# 3045_feature_transaction_avg_20_days           1.035750e+02
# 3045_feature_transaction_avg_30_days           1.036000e+02
# 3045_feature_transaction_avg_slope_5_10_days   1.001930e+00
# 3045_feature_transaction_avg_slope_5_20_days   1.000240e+00
# 3045_feature_transaction_avg_slope_5_30_days   1.000000e+00
# 3045_feature_transaction_avg_slope_10_20_days  9.983100e-01
# 3045_feature_transaction_avg_slope_10_30_days  9.980700e-01
# 3045_feature_transaction_avg_slope_20_30_days  9.997600e-01
# 3045_price                                     1.040000e+02
# 0050_price                                     1.267000e+02
# 3045_feature_price_avg_5_days                  1.036000e+02
# 3045_feature_price_avg_10_days                 1.034000e+02
# 3045_feature_price_avg_20_days                 1.035750e+02
# 3045_feature_price_avg_30_days                 1.036000e+02
# 3045_feature_price_avg_slope_5_10_days         1.001930e+00
# 3045_feature_price_avg_slope_5_20_days         1.000240e+00
# 3045_feature_price_avg_slope_5_30_days         1.000000e+00
# 3045_feature_price_avg_slope_10_20_days        9.983100e-01
# 3045_feature_price_avg_slope_10_30_days        9.980700e-01
# 3045_feature_price_avg_slope_20_30_days        9.997600e-01

# %%
# split data into training and testing

train_data = model_data.query('feature_year > 2012 and feature_year <= 2021').copy()
test_data = model_data.query('feature_year >= 2022').copy()

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import xgboost as xgb

tss = TimeSeriesSplit(n_splits=5, 
                      test_size=365, 
                      gap=1)

X_labels = [x for x in train_data.columns if 'feature_' in x]

y_labels = target + '_y'

fold = 0
preds = []
scores = []
val_result = []
for train_idx, val_idx in tss.split(train_data):
       print(f'Training fold : {fold}')
       
       train = train_data.iloc[train_idx]
       val = train_data.iloc[val_idx]

       X_train = train[X_labels]
       y_train = train[y_labels]

       X_val = val[X_labels]
       y_val = val[y_labels]

       reg = xgb.XGBRegressor(n_estimators = 1000
                              , learning_rate = 0.01
                              , early_stopping_rounds = 50
                              )

       reg.fit(X_train, y_train
               , eval_set = [(X_train,y_train),(X_val, y_val)]
               , verbose = 100
               )
       
       y_pred = reg.predict(X_val)
       preds.append(y_pred)
       score = np.sqrt(mean_squared_error(y_val, y_pred))
       scores.append(score)
       val_result.append(reg.evals_result())
       fold +=1
# Out:
# Training fold : 0
# [0]	validation_0-rmse:99.00012	validation_1-rmse:100.09083
# [100]	validation_0-rmse:36.62855	validation_1-rmse:37.39669
# [200]	validation_0-rmse:13.73264	validation_1-rmse:15.17872
# [300]	validation_0-rmse:5.24577	validation_1-rmse:7.70568
# [400]	validation_0-rmse:2.06431	validation_1-rmse:5.60304
# [500]	validation_0-rmse:0.86201	validation_1-rmse:5.10957
# [600]	validation_0-rmse:0.40300	validation_1-rmse:4.98137
# [700]	validation_0-rmse:0.22677	validation_1-rmse:4.93597
# [800]	validation_0-rmse:0.15019	validation_1-rmse:4.91815
# [900]	validation_0-rmse:0.10953	validation_1-rmse:4.91231
# [999]	validation_0-rmse:0.08653	validation_1-rmse:4.91031
# Training fold : 1
# [0]	validation_0-rmse:99.52604	validation_1-rmse:107.99148
# [100]	validation_0-rmse:36.71573	validation_1-rmse:42.54678
# [200]	validation_0-rmse:13.76069	validation_1-rmse:17.77268
# [300]	validation_0-rmse:5.31329	validation_1-rmse:8.78869
# [400]	validation_0-rmse:2.19173	validation_1-rmse:5.70780
# [500]	validation_0-rmse:1.02901	validation_1-rmse:4.63348
# [600]	validation_0-rmse:0.59069	validation_1-rmse:4.24857
# [700]	validation_0-rmse:0.41780	validation_1-rmse:4.09136
# [800]	validation_0-rmse:0.32477	validation_1-rmse:4.03258
# [900]	validation_0-rmse:0.27267	validation_1-rmse:4.00637
# [999]	validation_0-rmse:0.23602	validation_1-rmse:3.99934
# Training fold : 2
# [0]	validation_0-rmse:102.36310	validation_1-rmse:106.58014
# [100]	validation_0-rmse:37.70948	validation_1-rmse:38.92841
# [200]	validation_0-rmse:14.07600	validation_1-rmse:14.05933
# [300]	validation_0-rmse:5.38729	validation_1-rmse:5.59322
# [400]	validation_0-rmse:2.17052	validation_1-rmse:3.22421
# [500]	validation_0-rmse:0.99161	validation_1-rmse:2.81075
# [600]	validation_0-rmse:0.54195	validation_1-rmse:2.73252
# [700]	validation_0-rmse:0.38298	validation_1-rmse:2.71728
# [800]	validation_0-rmse:0.31087	validation_1-rmse:2.70534
# [900]	validation_0-rmse:0.27459	validation_1-rmse:2.69186
# [999]	validation_0-rmse:0.24499	validation_1-rmse:2.68269
# Training fold : 3
# [0]	validation_0-rmse:103.41897	validation_1-rmse:109.47872
# [100]	validation_0-rmse:38.05214	validation_1-rmse:41.98525
# [200]	validation_0-rmse:14.16830	validation_1-rmse:17.12355
# [300]	validation_0-rmse:5.40881	validation_1-rmse:8.94095
# [400]	validation_0-rmse:2.19748	validation_1-rmse:6.42684
# [500]	validation_0-rmse:1.04280	validation_1-rmse:5.63132
# [600]	validation_0-rmse:0.63291	validation_1-rmse:5.35065
# [700]	validation_0-rmse:0.48086	validation_1-rmse:5.24397
# [800]	validation_0-rmse:0.39913	validation_1-rmse:5.21538
# [900]	validation_0-rmse:0.34574	validation_1-rmse:5.18952
# [999]	validation_0-rmse:0.29693	validation_1-rmse:5.17809
# Training fold : 4
# [0]	validation_0-rmse:104.64429	validation_1-rmse:98.22430
# [100]	validation_0-rmse:38.50098	validation_1-rmse:34.51458
# [200]	validation_0-rmse:14.35403	validation_1-rmse:10.72943
# [300]	validation_0-rmse:5.48927	validation_1-rmse:2.79931
# [384]	validation_0-rmse:2.56620	validation_1-rmse:2.78667

# %%
result = reg.evals_result()

train_rmse = result['validation_0']['rmse']
val_rmse = result['validation_1']['rmse']
estimator = range(0, len(result['validation_1']['rmse']))
fig, ax = plt.subplots()

ax.plot(estimator, train_rmse)
ax.plot(estimator, val_rmse)
ax.set_xlabel('estimators')
ax.set_ylabel('RMSE')
ax.set_title('RMSE train vs.test')

ax.set_xlim(left=0, right=1000)
ax.legend(['Train', 'Test'])

plt.show()

# %%
# Predict

reg = xgb.XGBRegressor(n_estimators = 600
                            , learning_rate = 0.01
                            #, early_stopping_rounds = 50
                            )

reg.fit(X_train, y_train)


pred_test = reg.predict(test_data[X_labels])
y_test = test_data[y_labels]


figs, ax = plt.subplots()

ax.plot(test_data.index, y_test)
ax.plot(test_data.index, pred_test)

ax.legend(['Actual', 'Pred'])

plt.show()

#score = np.sqrt(mean_squared_error(pred_test, y_test))
      
#print(f'RMSE : {score:2f}')

# %%
test_data.tail(30)[[target + '_close', target +'_y', target +'_feature_close_avg_5_days']].to_clipboard()

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb

kf = KFold(n_splits=5
        #, random_state= 10
        , shuffle=True
        )


X_labels = [x for x in train_data.columns if 'feature_' in x]

y_labels = target + '_y'

fold = 0
preds = []
scores = []

for train_idx, val_idx in kf.split(train_data):
       print(f'Training fold : {fold}')
       
       train = train_data.iloc[train_idx]
       val = train_data.iloc[val_idx]

       X_train = train[X_labels]
       y_train = train[y_labels]

       X_val = val[X_labels]
       y_val = val[y_labels]

       print(f'Training size : {len(X_train)}')
       print(f'Val size : {len(X_val)}')
        
       reg = xgb.XGBRegressor(n_estimators = 1000
                              , early_stopping_rounds = 10
                              , learning_rate = 0.01
                              )

       reg.fit(X_train, y_train
               , eval_set = [(X_train,y_train),(X_val, y_val)]
               , verbose =100
               )
       
       y_pred = reg.predict(X_val)
       preds.append(y_pred)
       score = np.sqrt(mean_squared_error(y_val, y_pred))
       scores.append(score)
       fold +=1
# Out:
# Training fold : 0
# Training size : 1764
# Val size : 442
# [0]	validation_0-rmse:68.81090	validation_1-rmse:69.35389
# [100]	validation_0-rmse:25.33620	validation_1-rmse:25.57199
# [200]	validation_0-rmse:9.47384	validation_1-rmse:9.63135
# [300]	validation_0-rmse:3.66649	validation_1-rmse:3.84270
# [400]	validation_0-rmse:1.54644	validation_1-rmse:1.80978
# [500]	validation_0-rmse:0.79237	validation_1-rmse:1.13631
# [600]	validation_0-rmse:0.53195	validation_1-rmse:0.92399
# [700]	validation_0-rmse:0.43875	validation_1-rmse:0.84457
# [800]	validation_0-rmse:0.38587	validation_1-rmse:0.80455
# [900]	validation_0-rmse:0.33862	validation_1-rmse:0.77735
# [999]	validation_0-rmse:0.30676	validation_1-rmse:0.75641
# Training fold : 1
# Training size : 1765
# Val size : 441
# [0]	validation_0-rmse:68.87163	validation_1-rmse:69.11192
# [100]	validation_0-rmse:25.35594	validation_1-rmse:25.41440
# [200]	validation_0-rmse:9.47312	validation_1-rmse:9.49072
# [300]	validation_0-rmse:3.65802	validation_1-rmse:3.72947
# [400]	validation_0-rmse:1.53738	validation_1-rmse:1.72476
# [500]	validation_0-rmse:0.79507	validation_1-rmse:1.10670
# [600]	validation_0-rmse:0.53455	validation_1-rmse:0.92678
# [700]	validation_0-rmse:0.43589	validation_1-rmse:0.86653
# [800]	validation_0-rmse:0.37854	validation_1-rmse:0.84072
# [900]	validation_0-rmse:0.33045	validation_1-rmse:0.82025
# [999]	validation_0-rmse:0.28916	validation_1-rmse:0.80145
# Training fold : 2
# Training size : 1765
# Val size : 441
# [0]	validation_0-rmse:68.97518	validation_1-rmse:68.69953
# [100]	validation_0-rmse:25.39585	validation_1-rmse:25.30640
# [200]	validation_0-rmse:9.48993	validation_1-rmse:9.46049
# [300]	validation_0-rmse:3.66897	validation_1-rmse:3.68699
# [400]	validation_0-rmse:1.54838	validation_1-rmse:1.67291
# [500]	validation_0-rmse:0.79817	validation_1-rmse:1.01678
# [600]	validation_0-rmse:0.54995	validation_1-rmse:0.82856
# [700]	validation_0-rmse:0.45249	validation_1-rmse:0.76389
# [800]	validation_0-rmse:0.39939	validation_1-rmse:0.72781
# [900]	validation_0-rmse:0.34773	validation_1-rmse:0.69426
# [999]	validation_0-rmse:0.30263	validation_1-rmse:0.67267
# Training fold : 3
# Training size : 1765
# Val size : 441
# [0]	validation_0-rmse:68.99111	validation_1-rmse:68.63285
# [100]	validation_0-rmse:25.40170	validation_1-rmse:25.23836
# [200]	validation_0-rmse:9.48729	validation_1-rmse:9.43812
# [300]	validation_0-rmse:3.66511	validation_1-rmse:3.69221
# [400]	validation_0-rmse:1.54392	validation_1-rmse:1.66167
# [500]	validation_0-rmse:0.80399	validation_1-rmse:1.03140
# [600]	validation_0-rmse:0.55060	validation_1-rmse:0.84951
# [700]	validation_0-rmse:0.44742	validation_1-rmse:0.78415
# [800]	validation_0-rmse:0.39581	validation_1-rmse:0.75359
# [900]	validation_0-rmse:0.35704	validation_1-rmse:0.73246
# [999]	validation_0-rmse:0.32898	validation_1-rmse:0.71661
# Training fold : 4
# Training size : 1765
# Val size : 441
# [0]	validation_0-rmse:68.95015	validation_1-rmse:68.79878
# [100]	validation_0-rmse:25.38665	validation_1-rmse:25.36989
# [200]	validation_0-rmse:9.48412	validation_1-rmse:9.49801
# [300]	validation_0-rmse:3.67643	validation_1-rmse:3.73266
# [400]	validation_0-rmse:1.55709	validation_1-rmse:1.68960
# [500]	validation_0-rmse:0.81300	validation_1-rmse:1.04453
# [600]	validation_0-rmse:0.54191	validation_1-rmse:0.84101
# [700]	validation_0-rmse:0.43288	validation_1-rmse:0.76616
# [800]	validation_0-rmse:0.38561	validation_1-rmse:0.74111
# [900]	validation_0-rmse:0.33751	validation_1-rmse:0.71455
# [999]	validation_0-rmse:0.29848	validation_1-rmse:0.69554

# %%
result = reg.evals_result()

train_rmse = result['validation_0']['rmse']
val_rmse = result['validation_1']['rmse']
estimator = range(0, len(result['validation_1']['rmse']))
fig, ax = plt.subplots()

ax.plot(estimator, train_rmse)
ax.plot(estimator, val_rmse)
ax.set_xlabel('estimators')
ax.set_ylabel('RMSE')
ax.set_title('RMSE train vs.test')

ax.set_xlim(left=0, right=1000)
ax.legend(['Train', 'Test'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 result = reg.evals_result()
#       3 train_rmse = result['validation_0']['rmse']
#       4 val_rmse = result['validation_1']['rmse']
#
# File ~/opt/anaconda3/envs/finlab/lib/python3.9/site-packages/xgboost/sklearn.py:1213, in XGBModel.evals_result(self)
#    1211     evals_result = self.evals_result_
#    1212 else:
# -> 1213     raise XGBoostError(
#    1214         "No evaluation result, `eval_set` is not used during training."
#    1215     )
#    1217 return evals_result
#
# XGBoostError: No evaluation result, `eval_set` is not used during training.

# %%
# Predict
reg = xgb.XGBRegressor(n_estimators = 400
                            , learning_rate = 0.01
                            #, early_stopping_rounds = 50
                            )

reg.fit(X_train, y_train)


pred_test = reg.predict(test_data[X_labels])
y_test = test_data[y_labels]


figs, ax = plt.subplots()

ax.plot(test_data.index, test_data[target + '_close'], color = 'grey', linestyle = '--')
ax.plot(test_data.index, y_test)
ax.plot(test_data.index, pred_test)

ax.legend(['Close', 'Actual', 'Pred'])

plt.show()

#score = np.sqrt(mean_squared_error(pred_test, y_test))
       
#print(f'RMSE : {score:2f}')

# %%
import datetime

# %%
# Predict
reg = xgb.XGBRegressor(n_estimators = 400
                            , learning_rate = 0.01
                            #, early_stopping_rounds = 50
                            )

reg.fit(X_train, y_train)


pred_test = reg.predict(test_data[X_labels])
y_test = test_data[y_labels]


figs, ax = plt.subplots()

ax.plot(test_data.index, test_data[target + '_close'], color = 'grey', linestyle = '--')
ax.plot(test_data.index, y_test)
ax.plot(test_data.index, pred_test)

ax.set_xlim(datetime.date(2023,1,1),datetime.date(2023,6,30))
ax.legend(['Close', 'Actual', 'Pred'])

plt.show()

# %%
'''
# get target stock trading count
target_cnt = close[target].count()

# get stock list with at least 90% of target trading count for a fair corr comparison
cmp_target_list = (close.count() > (target_cnt * 0.9)).index

# create dataset for computing corr
corr_df = close[cmp_target_list].copy()

# computing corr matrix
corr = corr_df.corr()

high_postive_corr_stocks = (
    corr[target].sort_values()   # sort by corr score, asceding = true
    .index  # stock list 
    [-3:-1]  # ignore target
)

high_negative_corr_stocks = (
    corr[target].sort_values()   # sort by corr score, asceding = true
    .index  # stock list 
    [0:2] 
)
'''
# Out:
# '\n# get target stock trading count\ntarget_cnt = close[target].count()\n\n# get stock list with at least 90% of target trading count for a fair corr comparison\ncmp_target_list = (close.count() > (target_cnt * 0.9)).index\n\n# create dataset for computing corr\ncorr_df = close[cmp_target_list].copy()\n\n# computing corr matrix\ncorr = corr_df.corr()\n\nhigh_postive_corr_stocks = (\n    corr[target].sort_values()   # sort by corr score, asceding = true\n    .index  # stock list \n    [-3:-1]  # ignore target\n)\n\nhigh_negative_corr_stocks = (\n    corr[target].sort_values()   # sort by corr score, asceding = true\n    .index  # stock list \n    [0:2] \n)\n'

# %%
#reg.feature_importances_

fi = pd.DataFrame(data=reg.feature_importances_[:10],
                  index=reg.feature_names_in_[:10],
                  columns = ['importance']
                  )

fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
# Out:
# <Axes: title={'center': 'Feature Importance'}>
